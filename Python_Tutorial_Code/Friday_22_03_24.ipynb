# %%
def print_variable(x):
    phrase = f'My name is {x}'
    print(phrase)

print_variable("Naomi")
# Out:
# My name is Naomi

# %%
def sum_xy(x, y):
    z = x + y
    print(y)

sum_xy(x=10, y=5)
# Out:
# 5

# %%
def sum_xy(x, y):
    z = x + y
    print(y)

sum_xy(10, 5)

#either explain x=10, y=5 or use 10, 5 do not mix
# Out:
# 5

# %%
def minus_xy(x, y):
    z = x - y
    print(z)

minus_xy(8, 2)
# Out:
# 6

# %%
def minus_xy(x, y):
    z = x - y
    return z

minus_xy(8, 2)
# Out:
# 6

# %%
def maths_xy(x, y):
    minus = x - y
    plus = x + y
    return minus, plus

#print(maths_xy(100, 20))

answer = maths_xy(100, 20)
print(answer)
# Out:
# (80, 120)

# %%
def maths_xy(x, y):
    minus = x - y
    plus = x + y
    return minus, plus

x_minus_y, x_plus_y = maths_xy(100, 20)
print(x_minus_y)
print(x_plus_y)
# Out:
# 80
# 120

# %%
def more_maths(x, y):
    times = x * y
    divide = x / y
    return times, divide

x_times_y, x_divide_y = more_maths(100, 20)
print(x_times_y)
print(int(x_divide_y))
# Out:
# 2000
# 5

# %%
def function_1(x, y):
    return f'function 1 says x and y are {x}, {y}'

def function_2 (x, y):
    return f'function 2 says that x and y are {x}, {y}'

def nested_func(j, k):
    var_1 = function_1(j, k)
    var_2 = function_2(j, k)
    return var_1, var_2

print(nested_func('Hi', 'Hello'))
# Out:
# ('function 1 says x and y are Hi, Hello', 'function 2 says that x and y are Hi, Hello')

# %%
def forename(firstname):
    return f'Hello my forname is {firstname}'

def surname(lastname):
    return f'Hello my surname is {lastname}'

def fullname(fname, sname)
    return forename(fname), surname(sname)

names = fullname(fname = 'Naomi', sname = 'Bain')
print(names)
# Out:
#   Cell In[28], line 7
#     def fullname(fname, sname)
#                               ^
# SyntaxError: expected ':'

# %%
def my_forename(forename):
    return f'Hello, my name is {forename}'
def my_surname(surname):
    return f'My surname is {surname}'
def name_function(fname, sname):
    return my_forename(fname), my_surname(sname)
names = name_function(fname='Will', sname='Levack-Payne')
print(names)
# Out:
# ('Hello, my name is Will', 'My surname is Levack-Payne')

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv'
df = pd.read_csv(url)
df.head()
# Out:
#              Name   Period  House price index All property types  \
# 0  United Kingdom  1980-01                                 10.11
# 1  United Kingdom  1980-02                                 10.11
# 2  United Kingdom  1980-03                                 10.11
# 3  United Kingdom  1980-04                                 10.51
# 4  United Kingdom  1980-05                                 10.51
#
#    Average price All property types  \
# 0                             19273
# 1                             19273
# 2                             19273
# 3                             20044
# 4                             20044
#
#    Percentage change (monthly) All property types  \
# 0                                            3.94
# 1                                            3.94
# 2                                            3.94
# 3                                            4.00
# 4                                            4.00
#
#    Percentage change (yearly) All property types
# 0                                          28.59
# 1                                          28.59
# 2                                          28.59
# 3                                          24.15
# 4                                          24.15

# %%
mean_pct_change = df['Percentage change (monthly) All property types'].mean()

#print(mean_pct_change)

def change_checker(pct_change):
    if pct_change > mean_pct_change:
        return 'Greater than average'
    if pct_change < mean_pct_change:
        return ' Less than average'
    else:
        return 'Exactly average'
    
df['Change ratio'] = df['Percentage change (monthly) All property types'].apply(change_checker)

df
# Out:
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# 3                               20044
# 4                               20044
# ..                                ...
# 518                            282548
# 519                            283871
# 520                            285053
# 521                            288281
# 522                            289824
#
#      Percentage change (monthly) All property types  \
# 0                                              3.94
# 1                                              3.94
# 2                                              3.94
# 3                                              4.00
# 4                                              4.00
# ..                                              ...
# 518                                           -1.00
# 519                                            0.50
# 520                                            0.40
# 521                                            1.10
# 522                                            0.50
#
#      Percentage change (yearly) All property types          Change ratio
# 0                                            28.59  Greater than average
# 1                                            28.59  Greater than average
# 2                                            28.59  Greater than average
# 3                                            24.15  Greater than average
# 4                                            24.15  Greater than average
# ..                                             ...                   ...
# 518                                           3.20     Less than average
# 519                                           2.50     Less than average
# 520                                           1.60     Less than average
# 521                                           1.90     Less than average
# 522                                           0.60     Less than average
#
# [523 rows x 7 columns]

# %%
mean_price = df['Average price All property types'].mean()

#print(mean_pct_change)

def change_checker(price):
    if price > mean_price:
        return 'Greater than average'
    if price < mean_price:
        return ' Less than average'
    else:
        return 'Exactly average'
    
df['Price check'] = df['Average price All property types'].apply(price_checker)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 13
#      10     else:
#      11         return 'Exactly average'
# ---> 13 df['Price check'] = df['Average price All property types'].apply(price_checker)
#      15 df
#
# NameError: name 'price_checker' is not defined

# %%
mean_price = df['Average price All property types'].mean()
# print(mean_pct_change)
def price_checker(price):
    if price > mean_price:
        return 'Greater than average'
    if price < mean_price:
        return 'Less than average'
    else:
        return 'Exactly Average'
df['Price check'] = df['Average price All property types'].apply(price_checker)
df
# Out:
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# 3                               20044
# 4                               20044
# ..                                ...
# 518                            282548
# 519                            283871
# 520                            285053
# 521                            288281
# 522                            289824
#
#      Percentage change (monthly) All property types  \
# 0                                              3.94
# 1                                              3.94
# 2                                              3.94
# 3                                              4.00
# 4                                              4.00
# ..                                              ...
# 518                                           -1.00
# 519                                            0.50
# 520                                            0.40
# 521                                            1.10
# 522                                            0.50
#
#      Percentage change (yearly) All property types          Change ratio  \
# 0                                            28.59     Less than average
# 1                                            28.59     Less than average
# 2                                            28.59     Less than average
# 3                                            24.15     Less than average
# 4                                            24.15     Less than average
# ..                                             ...                   ...
# 518                                           3.20  Greater than average
# 519                                           2.50  Greater than average
# 520                                           1.60  Greater than average
# 521                                           1.90  Greater than average
# 522                                           0.60  Greater than average
#
#               Price check
# 0       Less than average
# 1       Less than average
# 2       Less than average
# 3       Less than average
# 4       Less than average
# ..                    ...
# 518  Greater than average
# 519  Greater than average
# 520  Greater than average
# 521  Greater than average
# 522  Greater than average
#
# [523 rows x 8 columns]
